# %% [markdown]
# # Many To Many Connections

# %%
import json
import sqlite3

# %%
conn=sqlite3.connect('rosterdb.sqlite')
cur=conn.cursor()

# %%
cur.executescript('''
DROP TABLE IF EXISTS User;
DROP TABLE IF EXISTS Member;
DROP TABLE IF EXISTS Course;

CREATE TABLE User(
    id INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name TEXT UNIQUE
);

CREATE TABLE Course(
    id INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    title TEXT UNIQUE
);

CREATE TABLE Member(
    user_id INTEGER,
    course_id INTEGER,
    PRIMARY KEY (user_id, course_id)
);

''')

# %%
fname=raw_input('Enter a file name:')
if(len(fname)<1): fname='roster_data.json'

str_data=open(fname).read()
json_data=json.loads(str_data)

for entry in json_data:
    name = entry[0]
    title=entry[1]
    
    print name, title
    
    cur.execute('''INSERT OR IGNORE INTO User (name)
        VALUES (?)''', (name, ))
    cur.execute('SELECT id FROM User WHERE name = ?', (name, ))
    user_id=cur.fetchone()[0]
    
    cur.execute('''INSERT OR IGNORE INTO Course (title)
        VALUES (?)''', (title, ))
    cur.execute('SELECT id FROM Course WHERE title=?', (title, ))
    course_id=cur.fetchone()[0]
    
    cur.execute('''INSERT OR REPLACE INTO Member (user_id, course_id)
        VALUES (?, ?)''', (user_id, course_id))
    
    conn.commit()
# Out:
# Enter a file name:
# Charley si110
# Mea si110
# Hattie si110
# Lyena si110
# Keziah si110
# Ellyce si110
# Thalia si110
# Meabh si110
# Aria si110
# Reena si110
# Ioannis si110
# Reily si110
# Sidharth si110
# Keiara si110
# Yann si110
# Marykate si110
# Dylan si110
# Kiran si110
# Faizaan si110
# Aneshia si110
# Kamron si110
# Allen si110
# Marshall si110
# Rosa si106
# Nora si106
# Mairin si106
# Zendel si106
# Honie si106
# Betsy si106
# Davie si106
# Larissa si106
# Shaurya si106
# Shania si106
# Sorcha si106
# Jeanna si106
# Temba si106
# Buse si106
# Mohammed si106
# Kayah si106
# Kareena si106
# Dineo si106
# Philippa si106
# Lia si206
# Sharlyn si206
# Linton si206
# Temilade si206
# Areez si206
# MacCartney si206
# Abubakar si206
# Derryn si206
# Elan si206
# Vikki si206
# Anisa si206
# Klevis si206
# Tait si206
# Rhea si206
# Pearsen si206
# Willow si206
# Skye si206
# Caralee si206
# Charlee si206
# Karyn si206
# Elana si206
# Maggie si206
# Eryk si206
# Zulaikha si301
# Elshan si301
# Anastasia si301
# Connar si301
# Anay si301
# Jayla si301
# Cai si301
# Zijie si301
# Riana si301
# Codie si301
# Colette si301
# Lucee si301
# Tatiana si301
# Zhong si301
# Lowri si301
# Maggy si301
# Basher si301
# Tanika si301
# Aria si301
# Belle si301
# Laranya si301
# Dayna si301
# Elleanne si301
# Maanav si310
# Tamta si310
# Frazer si310
# Sacha si310
# Aidan si310
# Abel si310
# Ahtasham si310
# Avinash si310
# Colette si310
# Cohen si310
# Rori si310
# Youer si310
# Jamey si310
# Makenzie si310
# Ida si310
# Alexzander si310
# Kavita si310
# Talia si310
# Anthony si310
# Elona si334
# Inan si334
# Caoilainn si334
# Ainsley si334
# Franciszek si334
# Corrie si334
# Nolan si334
# Makala si334
# Obieluem si334
# Camryn si334
# Honie si334
# Ole si334
# Raine si334
# Tyllor si334
# Diane si334
# Cullen si334
# Taylor si334
# Schekina si334
# Kensey si334
# Zhi si334
# Kiran si334
# Tymoteusz si334
# Windsor si363
# Kashish si363
# Diarmid si363
# Laura si363
# Jaskaran si363
# Presley si363
# Brooklynn si363
# Heddle si363
# Travis si363
# Alx si363
# Airen si363
# Erika si363
# Mackie si363
# Wen si363
# Seaan si363
# Meghan si363
# Ryaan si363
# Imogem si364
# Harlie si364
# Ronnie si364
# Lucca si364
# Shanelle si364
# Ieuan si364
# Anneliese si364
# Simon si364
# Sorche si364
# Nawal si364
# Adelaide si364
# Rhia si364
# Katarzyna si364
# LLeyton si364
# Enzo si364
# Declan si364
# Emelie si364
# Baillie si364
# Shola si364
# Jenna si422
# Miles si422
# Sakina si422
# Melanie si422
# Bailie si422
# Cassy si422
# Nikash si422
# Hebe si422
# Sia si422
# Skyla si422
# Jamaal si422
# Keanna si422
# Vanya si422
# Temperance si422
# Hafiza si422
# Alx si422
# Brigitte si422
# Eliana si422
# Kayden si422
# Man si422
# Jaydyn si422
# Soukina si430
# Stephenjunior si430
# Buddy si430
# Holly si430
# Kamilia si430
# Cassie si430
# Kris si430
# Maia si430
# Abel si430
# Tamika si430
# Deano si430
# Rosa si430
# Georgia si430
# Louie si430
# Kassie si430
# Mutinta si430
# Manwen si430

# %% [markdown]
# ## Assignment

# %%
conn=sqlite3.connect('rosterdb_assignment.sqlite')
cur=conn.cursor()

# %%
cur.executescript('''
DROP TABLE IF EXISTS User;
DROP TABLE IF EXISTS Member;
DROP TABLE IF EXISTS Course;

CREATE TABLE User(
    id INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name TEXT UNIQUE
);

CREATE TABLE Course(
    id INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    title TEXT UNIQUE
);

CREATE TABLE Member(
    user_id INTEGER,
    course_id INTEGER,
    role INTEGER,
    PRIMARY KEY (user_id, course_id)
);

''')

# %%
fname=raw_input('Enter a file name:')
if(len(fname)<1): fname='roster_data_assignment.json'

str_data=open(fname).read()
json_data=json.loads(str_data)

for entry in json_data:
    name = entry[0]
    title=entry[1]
    role=entry[2]
    
    print name, title, role
    
    cur.execute('''INSERT OR IGNORE INTO User (name)
        VALUES (?)''', (name, ))
    cur.execute('SELECT id FROM User WHERE name = ?', (name, ))
    user_id=cur.fetchone()[0]
    
    cur.execute('''INSERT OR IGNORE INTO Course (title)
        VALUES (?)''', (title, ))
    cur.execute('SELECT id FROM Course WHERE title=?', (title, ))
    course_id=cur.fetchone()[0]
    
    cur.execute('''INSERT OR REPLACE INTO Member (user_id, course_id, role)
        VALUES (?, ?, ?)''', (user_id, course_id, role))
    
    conn.commit()
# Out:
# Enter a file name:roster_data_assignment.json
# Lumi si110 1
# Mirza si110 0
# Tianna si110 0
# Clarke si110 0
# Charli si110 0
# Kaceylee si110 0
# Tasia si110 0
# Martin si422 0
# Scot si422 0
# Nikos si430 1
# Marcus si430 0
# Andrei si430 0
# Yu si430 0
# Kizzy si430 0
# Shazina si430 0
# Mackena si430 0
# Kori si430 0
# Mohd si430 0
# Paige si430 0
# Arun si430 0
# Limbiadhe si430 0
# Aazaan si430 0
# Ivana si430 0
# Leya si430 0
# Dominik si430 0
# Jaelyn si430 0
# Deegan si430 0
# Orrick si430 0
# Alice si430 0
# Rahel si430 0
# Temba si430 0
# Makayla si430 0
# Kalen si430 0
# Melica si430 0

# %%
cur.execute('''
    SELECT hex(User.name || Course.title || Member.role ) AS X FROM 
    User JOIN Member JOIN Course 
    ON User.id = Member.user_id AND Member.course_id = Course.id
    ORDER BY X''')
query=cur.fetchall()

# %%
for item in query:
    print item
# Out:
# (u'416164616D736934323230',)
# (u'41616B72697469736934323230',)
# (u'41617269666168736932303630',)
# (u'41617A61616E736934333030',)
# (u'4162697961736931313030',)
# (u'4164656C65736933333430',)
# (u'41647269616E736932303630',)
# (u'41647269656E6E65736933313030',)
# (u'416C616E6173736931303630',)
# (u'416C616E6973736932303630',)
# (u'416C626572736933363430',)
# (u'416C6578696E61736934323230',)
# (u'416C66736933363330',)
# (u'416C696365736934333030',)
# (u'416C6C696168736931313030',)
# (u'416D61726168736932303630',)
# (u'416D656C6961736933363330',)
# (u'416D696E6168736932303630',)
# (u'416E64726569736934333030',)
# (u'416E65696C7961736933363430',)
# (u'416E67656C6963736933313030',)
# (u'416E697368736933333430',)
# (u'416E6D6172736931313030',)
# (u'416E6E6162656C736933363430',)
# (u'416E6E656C6965736931303630',)
# (u'416E6E65726F79736933313030',)
# (u'416F69626865736931313030',)
# (u'4172636869746861736933363330',)
# (u'417267796C6C736933303130',)
# (u'41726C6F736931303630',)
# (u'41726D616E736931313030',)
# (u'4172756E736932303630',)
# (u'4172756E736934333030',)
# (u'417365656C736933333430',)
# (u'417374726964736932303630',)
# (u'41756C6179736931303630',)
# (u'4176696E617368736933303130',)
# (u'417964616E736933363330',)
# (u'41796D616E736933333430',)
# (u'417972656E736932303630',)
# (u'417973686168736934323230',)
# (u'42616C6579736931313030',)
# (u'42617965736931303630',)
# (u'42656175736933303130',)
# (u'42656C69657665736933333430',)
# (u'42657468616E79736934323230',)
# (u'4265747479736931313030',)
# (u'4269736D61736933303130',)
# (u'426C61696E65736931303630',)
# (u'426F626269736933333430',)
# (u'426F77736934323230',)
# (u'4272616E646F6E6C6565736933333430',)
# (u'4272616E646F6E736933333430',)
# (u'42726F6479736933363330',)
# (u'42726F67616E736933363330',)
# (u'42757365736932303630',)
# (u'436164796E736933303130',)
# (u'43616564796E736934323230',)
# (u'4361656C616E736932303630',)
# (u'4361656C796E736931303630',)
# (u'436169726E736933313030',)
# (u'43616C6579736934323230',)
# (u'43616C6962736933333430',)
# (u'43616E64696365736933333430',)
# (u'4361707269736934323230',)
# (u'436174686C65656E736931303630',)
# (u'436563696C79736931303630',)
# (u'43656F6C736932303630',)
# (u'436861726C69736931313030',)
# (u'436861726C6F747465736933313030',)
# (u'4368656E6169736932303630',)
# (u'436C61726B65736931313030',)
# (u'436C61726B736931313030',)
# (u'436F6261696E736933313030',)
# (u'436F6469736933363330',)
# (u'436F6C696E736933333430',)
# (u'436F6E6C696E736934323230',)
# (u'436F736D6F736931303630',)
# (u'43726F6D626965736933313030',)
# (u'446165677975736931313030',)
# (u'446169746869736932303630',)
# (u'44616E69656C6C65736933303130',)
# (u'44616F6F64736933313030',)
# (u'4461726379736931313030',)
# (u'4461726568736933363330',)
# (u'4465636C79616E736933303130',)
# (u'44656567616E736934333030',)
# (u'44656E6E79736933363430',)
# (u'446572696E736933363330',)
# (u'4468616E69736933303130',)
# (u'4468796961736931313030',)
# (u'44696573656C736933313030',)
# (u'44696C6C79736931303630',)
# (u'44696F6E65736933303130',)
# (u'446F6D696E696B736934333030',)
# (u'447562686C696E6E736934323230',)
# (u'44756E63616E736933363430',)
# (u'4561626861736931313030',)
# (u'456164656E736933333430',)
# (u'45696C65616E736934323230',)
# (u'456C656E69736932303630',)
# (u'456C69616E61736931313030',)
# (u'456C697461736931313030',)
# (u'456C69796168736933363330',)
# (u'456C697A61736932303630',)
# (u'456C6C6961736932303630',)
# (u'456C6C696365736933363330',)
# (u'456D69736933363430',)
# (u'456E7269636F736933363330',)
# (u'4572656E736933363330',)
# (u'45736861616C736932303630',)
# (u'457374656C6C65736931313030',)
# (u'457374686572736934323230',)
# (u'45757068656D6961736931313030',)
# (u'46696E6E736931303630',)
# (u'4672616E636973636F736933363430',)
# (u'467275696E736934323230',)
# (u'476176696E736933363430',)
# (u'47656D696D61736932303630',)
# (u'47656F72676961736934323230',)
# (u'476C6173636F7474736931313030',)
# (u'476F6D616E61736934323230',)
# (u'47726567736933313030',)
# (u'477573746176736931303630',)
# (u'4777656E736931313030',)
# (u'48616E65656168736933313030',)
# (u'48616F736933313030',)
# (u'486172696B726973686E61736933303130',)
# (u'4861727279736934323230',)
# (u'486173656562736933313030',)
# (u'4861796C6579736933303130',)
# (u'48697261736933303131',)
# (u'48756D61797261736933363330',)
# (u'496E6479736931303630',)
# (u'496E73697961736933303130',)
# (u'4976616E61736934333030',)
# (u'4A61656C796E736934333030',)
# (u'4A6165736931303630',)
# (u'4A616961736933313030',)
# (u'4A6169736932303630',)
# (u'4A616D6965736933363430',)
# (u'4A616E6165736933303130',)
# (u'4A616E6E6168736932303630',)
# (u'4A61726E6F736934323230',)
# (u'4A65616E6E6965736931313030',)
# (u'4A65656D6965736932303630',)
# (u'4A656E73696E65736932303630',)
# (u'4A65727279736933313030',)
# (u'4A6F686E736F6E736932303630',)
# (u'4A6F726469736932303630',)
# (u'4A6F726973736933363331',)
# (u'4A6F726A6961736932303630',)
# (u'4A6F73687561736933363330',)
# (u'4A756C696574736933313030',)
# (u'4A757374696E736933333430',)
# (u'4B61616E736931303630',)
# (u'4B616365796C6565736931313030',)
# (u'4B61636579736932303630',)
# (u'4B6164696E736933363431',)
# (u'4B61696C65696768736933303130',)
# (u'4B61696C796E736933333430',)
# (u'4B616C6562736931303630',)
# (u'4B616C656E736934333030',)
# (u'4B617269736933313030',)
# (u'4B617269737361736933313030',)
# (u'4B6174686C65656E736933333430',)
# (u'4B61746965736932303630',)
# (u'4B6179616D736932303630',)
# (u'4B61796C616E736933333430',)
# (u'4B61796C61736934323230',)
# (u'4B61796C796E6E736931313030',)
# (u'4B65696C6565736933363330',)
# (u'4B656C6C616E736931313030',)
# (u'4B656C7369736931313030',)
# (u'4B656E7A6965736931313030',)
# (u'4B656F736933303130',)
# (u'4B65726973736933363330',)
# (u'4B6576616E736934323230',)
# (u'4B657A736934323230',)
# (u'4B6865616E6E61736933363330',)
# (u'4B69656E616E736931303630',)
# (u'4B697A7A79736934333030',)
# (u'4B6C617261736933363330',)
# (u'4B6F7269736934333030',)
# (u'4B6F7272696E736934323230',)
# (u'4B79616E736933333430',)
# (u'4B796C65736933363330',)
# (u'4C617572656E6365736933363330',)
# (u'4C6175726965736931313030',)
# (u'4C65696768616D736931313030',)
# (u'4C65696768616E6E736934323230',)
# (u'4C65696C616E69736932303630',)
# (u'4C65696C616E69736933333430',)
# (u'4C656974656E736933363330',)
# (u'4C656E6F736933313030',)
# (u'4C656E7A79736934323230',)
# (u'4C657474696365736933303130',)
# (u'4C657961736934333030',)
# (u'4C696D626961646865736934333030',)
# (u'4C696E64736179736934323231',)
# (u'4C69766961736933363330',)
# (u'4C6C616E61736934323230',)
# (u'4C6F6B657368736934323230',)
# (u'4C6F747461736932303630',)
# (u'4C756D69736931313031',)
# (u'4D61617269796168736933363330',)
# (u'4D616369736931313030',)
# (u'4D61636B656E61736934333030',)
# (u'4D6164696E6168736931303630',)
# (u'4D616B61796C61736934333030',)
# (u'4D616E74656A736932303630',)
# (u'4D6172637573736934333030',)
# (u'4D617269796168736934323230',)
# (u'4D617274696E736934323230',)
# (u'4D61756E61736933363330',)
# (u'4D634B616465736934323230',)
# (u'4D656767736931303630',)
# (u'4D6569736861736931313030',)
# (u'4D656C696361736934333030',)
# (u'4D656C6973736934323230',)
# (u'4D696B6F6C616A736933363330',)
# (u'4D696C6573736932303630',)
# (u'4D69727A61736931313030',)
# (u'4D6F68616D6D6564736934323230',)
# (u'4D6F68616E6164736933313030',)
# (u'4D6F68616E6164736933363430',)
# (u'4D6F6864736934333030',)
# (u'4D6F726E616368736931303630',)
# (u'4D6F726E616368736933313030',)
# (u'4D6F7272616E736931313030',)
# (u'4D7568616D6D6164736932303630',)
# (u'4D757279616D736931313030',)
# (u'4E616966736933313030',)
# (u'4E616B6569736861736933313030',)
# (u'4E6172766963736931313030',)
# (u'4E617368736934323230',)
# (u'4E617468616E69616C736933333430',)
# (u'4E657665736933333430',)
# (u'4E69616C6C736933313031',)
# (u'4E69616C6C736934323230',)
# (u'4E696861616C736934323230',)
# (u'4E696B6F73736934333031',)
# (u'4E696F6D69736931303631',)
# (u'4E69726F736931313030',)
# (u'4E6F726561736933303130',)
# (u'4E75616461736933333430',)
# (u'4F6C69766572736933333430',)
# (u'4F6C75776174696D696C6568696E736932303630',)
# (u'4F726C616E646F736933363430',)
# (u'4F727269636B736934333030',)
# (u'4F7368756E736933363430',)
# (u'4F7A7A79736934323230',)
# (u'5061696765736934333030',)
# (u'5065617273656E736933363330',)
# (u'506572656772696E65736933363330',)
# (u'50726162686173656573736933363330',)
# (u'50726974687669736931313030',)
# (u'526168656C736934333030',)
# (u'52616E69796168736931303630',)
# (u'52656564736932303631',)
# (u'526567616E736934323230',)
# (u'526567676965736933303130',)
# (u'5265696C6C79736932303630',)
# (u'526875616E736933313030',)
# (u'52696365736933333430',)
# (u'52696C6579736933303130',)
# (u'5269736869736931313030',)
# (u'5269736869736934323230',)
# (u'526F62626965736932303630',)
# (u'526F6265727461736933333430',)
# (u'526F62696E736933333430',)
# (u'526F6D6579736933333430',)
# (u'526F6E61736934323230',)
# (u'526F73616E67656C736934323230',)
# (u'526F737369736933313030',)
# (u'52756172696468736933313030',)
# (u'52756279736933363330',)
# (u'52756279736934323230',)
# (u'527569736933363430',)
# (u'5279657365736931313030',)
# (u'53616669736932303630',)
# (u'536168616962736933363430',)
# (u'5361696D736933333430',)
# (u'53616A6964736931303630',)
# (u'53616C61687564696E736934323230',)
# (u'53616D6972736933313030',)
# (u'53616E69796168736931303630',)
# (u'53636F74736934323230',)
# (u'536565726174736931313030',)
# (u'536572656E61736932303630',)
# (u'5368616E616465736933313030',)
# (u'536861756E74656C736934323230',)
# (u'5368617A696E61736934333030',)
# (u'5368656C626965736931303630',)
# (u'5368657277796E736934323230',)
# (u'53696F7578736965736933333430',)
# (u'5369756268616E736933363430',)
# (u'536F706869736934323230',)
# (u'536F72636865736932303630',)
# (u'53756B6869736931303630',)
# (u'53756D6D6572736933313030',)
# (u'53757A616E6E6168736931303630',)
# (u'54616265746861736933363430',)
# (u'54616D6D617261736931313030',)
# (u'54616D6D69736933313030',)
# (u'54616D7461736934323230',)
# (u'5461736961736931313030',)
# (u'5461736E696D736933363330',)
# (u'5465696768656E736931313030',)
# (u'54656D6261736934333030',)
# (u'5465797969626168736932303630',)
# (u'54686F6D6173736933333431',)
# (u'5469616E6E61736931313030',)
# (u'5469616E736931303630',)
# (u'54696D7563696E736933303130',)
# (u'5469726565736934323230',)
# (u'56616C656E736934323230',)
# (u'56696E63656E7A6F736932303630',)
# (u'56697468756A616E736931313030',)
# (u'57657A69736933333430',)
# (u'57696B746F726961736933303130',)
# (u'576F6A6369656368736931313030',)
# (u'59616E67736933333430',)
# (u'5961726973736931313030',)
# (u'596F72676F73736931303630',)
# (u'5975736934333030',)
# (u'5A6163686172696168736933333430',)
# (u'5A6168696465736934323230',)
# (u'5A65687261736931313030',)
# (u'5A6F68616972736934323230',)
